# %%
import pandas as pd
pd.set_option('display.max_columns',50)

import numpy as np

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True)

# %%
basics = pd.read_csv('Data/title.basics.tsv.gz', sep='\t', low_memory=False)

# %%
basics
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10017006  tt9916848  tvEpisode              Episode #3.17
# 10017007  tt9916850  tvEpisode              Episode #3.19
# 10017008  tt9916852  tvEpisode              Episode #3.20
# 10017009  tt9916856      short                   The Wind
# 10017010  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
ratings = pd.read_csv('Data/title.ratings.tsv.gz', sep='\t', low_memory=False)

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1988
# 1        tt0000002            5.8       265
# 2        tt0000003            6.5      1849
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2632
# ...            ...            ...       ...
# 1331487  tt9916730            8.3        10
# 1331488  tt9916766            7.0        21
# 1331489  tt9916778            7.2        36
# 1331490  tt9916840            7.5         7
# 1331491  tt9916880            7.0         7
#
# [1331492 rows x 3 columns]

# %%
akas = pd.read_csv('Data/title-akas-us-only.csv', low_memory=False)

# %%
akas
# Out:
#            titleId  ordering                                      title  \
# 0        tt0000001         6                                 Carmencita
# 1        tt0000002         7                     The Clown and His Dogs
# 2        tt0000005        10                           Blacksmith Scene
# 3        tt0000005         1                        Blacksmithing Scene
# 4        tt0000005         6                        Blacksmith Scene #1
# ...            ...       ...                                        ...
# 1452559  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 1452560  tt9916620         1                          The Copeland Case
# 1452561  tt9916702         1              Loving London: The Playground
# 1452562  tt9916756         1                   Pretty Pretty Black Girl
# 1452563  tt9916764         1                                         38
#
#         region language        types             attributes isOriginalTitle
# ...

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe.  
# According to project instructions the akas has already been filtered and non us movies have already been removed so this why we used as in (akas
# We used akas 'titleId' and basics 'tconst' to connect them since these both mean the same in both dataframes  
# ou can use panda's .isin() method to remove non-US movies from title basics 
filter_us_titles = basics['tconst'].isin(akas['titleId'])
basics = basics[filter_us_titles]
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10016872  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10016901  tt9916620     movie                            The Copeland Case
# 10016939  tt9916702     short                Loving London: The Playground
# 10016962  tt9916756     short                     Pretty Pretty Black Girl
# 10016966  tt9916764     short                                           38
#
# ...

# %%
basics = basics.replace({'\\N':np.nan})

# %%
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10016872  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10016901  tt9916620     movie                            The Copeland Case
# 10016939  tt9916702     short                Loving London: The Playground
# 10016962  tt9916756     short                     Pretty Pretty Black Girl
# 10016966  tt9916764     short                                           38
#
# ...

# %%
# Dropping Null values from Drug column
basics = basics.dropna(subset=["runtimeMinutes", "genres"])

# %%
# by running basics again you can see that titleType hasn't been filtered yet to all movies so need to use = on next step
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10016704  tt9916214     short                              Drown the Clown
# 10016724  tt9916254     video                         Big Tit Cream Pie 32
# 10016770  tt9916348     video                        Ancient World Exposed
# 10016777  tt9916362     movie                                        Coven
# 10016872  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
#
# ...

# %%
# This creates a view with movies only but doesn't save it need to save it on next step with =
basics.loc[basics['titleType']=='movie']
# Out:
#              tconst titleType                    primaryTitle  \
# 8         tt0000009     movie                      Miss Jerry
# 144       tt0000147     movie   The Corbett-Fitzsimmons Fight
# 570       tt0000574     movie     The Story of the Kelly Gang
# 587       tt0000591     movie                The Prodigal Son
# 672       tt0000679     movie  The Fairylogue and Radio-Plays
# ...             ...       ...                             ...
# 10016366  tt9915436     movie               Vida em Movimento
# 10016544  tt9915872     movie            The Last White Witch
# 10016684  tt9916170     movie                   The Rehearsal
# 10016693  tt9916190     movie                       Safeguard
# 10016777  tt9916362     movie                           Coven
#
#                            originalTitle isAdult startYear endYear  \
# 8                             Miss Jerry       0      1894     NaN
# 144        The Corbett-Fitzsimmons Fight       0      1897     NaN
# ...

# %%
# this will save with only movie columns
basics = basics.loc[basics['titleType']=='movie']

# %%
basics
# Out:
#              tconst titleType                    primaryTitle  \
# 8         tt0000009     movie                      Miss Jerry
# 144       tt0000147     movie   The Corbett-Fitzsimmons Fight
# 570       tt0000574     movie     The Story of the Kelly Gang
# 587       tt0000591     movie                The Prodigal Son
# 672       tt0000679     movie  The Fairylogue and Radio-Plays
# ...             ...       ...                             ...
# 10016366  tt9915436     movie               Vida em Movimento
# 10016544  tt9915872     movie            The Last White Witch
# 10016684  tt9916170     movie                   The Rehearsal
# 10016693  tt9916190     movie                       Safeguard
# 10016777  tt9916362     movie                           Coven
#
#                            originalTitle isAdult startYear endYear  \
# 8                             Miss Jerry       0      1894     NaN
# 144        The Corbett-Fitzsimmons Fight       0      1897     NaN
# ...

# %%
# Convert startYear to a float dtype
basics['startYear'] = basics['startYear'].astype(float)

# %%
#checking of data type has changed and thats yes 
basics['startYear'].dtypes
# Out:
# dtype('float64')

# %%
# gpimf pm 
basics.loc[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2022)]
# Out:
#              tconst titleType  \
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# 67666     tt0069049     movie
# 86793     tt0088751     movie
# 93930     tt0096056     movie
# ...             ...       ...
# 10016149  tt9914942     movie
# 10016544  tt9915872     movie
# 10016684  tt9916170     movie
# 10016693  tt9916190     movie
# 10016777  tt9916362     movie
#
#                                                primaryTitle  \
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# 67666                            The Other Side of the Wind
# 86793                                     The Naked Monster
# 93930                                  Crime and Punishment
# ...                                                     ...
# 10016149                             Life Without Sara Amat
# 10016544                               The Last White Witch
# ...

# %%
basics = basics.loc[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2022)]

# %%
# Eliminate movies that include "Documentary" in genre:
# You will need to create a filter for if the movie's value in the genres column contains the word Documentary.
filter_documentaries = basics['genres'].str.contains('Documentary')

# %%
# Exclude movies in the documentary category.
# You will also want to use the ~ operator to take the inverse of your Trues/Falses.
basics = basics[~filter_documentaries]

# %%
basics
# Out:
#              tconst titleType  \
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# 67666     tt0069049     movie
# 86793     tt0088751     movie
# 93930     tt0096056     movie
# ...             ...       ...
# 10016149  tt9914942     movie
# 10016544  tt9915872     movie
# 10016684  tt9916170     movie
# 10016693  tt9916190     movie
# 10016777  tt9916362     movie
#
#                                                primaryTitle  \
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# 67666                            The Other Side of the Wind
# 86793                                     The Naked Monster
# 93930                                  Crime and Punishment
# ...                                                     ...
# 10016149                             Life Without Sara Amat
# 10016544                               The Last White Witch
# ...

# %%
# 5 Display a final preview of your filtered title basics and save to a csv
#  Display the .info() and .head() of your final title basics DataFrame.
# Tip: You should have ~80,000 rows left. If you have significantly more or less, double-check your filtering steps.
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86979 entries, 34802 to 10016777
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          86979 non-null  object
#  1   titleType       86979 non-null  object
#  2   primaryTitle    86978 non-null  object
#  3   originalTitle   86978 non-null  object
#  4   isAdult         86979 non-null  object
#  5   startYear       86979 non-null  float64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  86979 non-null  object
#  8   genres          86979 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 6.6+ MB

# %%
# Save the data to a CSV file in your Data folder
basics.to_csv("Data/Title_Basics.csv", index=False)

# %%
ratings.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1331492 entries, 0 to 1331491
# Series name: tconst
# Non-Null Count    Dtype
# --------------    -----
# 1331492 non-null  bool
# dtypes: bool(1)
# memory usage: 1.3 MB

# %%
ratings = pd.read_csv('Data/title.ratings.tsv.gz', sep='\t')

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1331492 entries, 0 to 1331491
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1331492 non-null  object
#  1   averageRating  1331492 non-null  float64
#  2   numVotes       1331492 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.5+ MB

# %%
# ???????? 
#6 Load and filter the title ratings file
# Load the title ratings data into a dataframe.
# Keep only movies that are included in your final title basics dataframe.
# Hint: Filter ratings using title basics similarly to how you filtered basics with AKAs:

ratings = ratings[ratings['tconst'].isin(basics['tconst'])]

# %%
# 7) Display a final preview of your filtered title ratings and save to a csv
# Use the same approach as you did for saving title basics.

ratings = ratings.replace({'\\N':np.nan})

# %%
# ???????/ why does it say all false? 
ratings
# Out:
#             tconst  averageRating  numVotes
# 17961    tt0035423            6.4     87153
# 40764    tt0062336            6.4       175
# 46645    tt0069049            6.7      7754
# 63640    tt0088751            5.2       336
# 69953    tt0096056            5.6       846
# ...            ...            ...       ...
# 1331411  tt9914942            6.6       178
# 1331437  tt9915872            6.4         9
# 1331450  tt9916170            7.0         7
# 1331451  tt9916190            3.7       243
# 1331462  tt9916362            6.4      5422
#
# [71900 rows x 3 columns]

# %%
# Save the data to a CSV file in your Data folder
ratings.to_csv("Data/Title_ratings.csv", index=False)
